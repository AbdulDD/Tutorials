# %% [markdown]
# # Importing Libraries and Dataset

# %%
import pandas as pd

DF = pd.read_csv("../input/simple-dataset-for-easy-practice-for-beginners/BrandEDA (1).csv")

# %%
from distutils.dir_util import copy_tree
FD ='../input/addfunct'
TD= './'
copy_tree(FD, TD)
# Out:
# ['./Add.txt',
#  './LICENSE',
#  './README.md',
#  './mean-encoding-tutorial.ipynb',
#  './add-function.ipynb',
#  './Add.py']

# %%
# %load Add.py
# %load Add.py
def ad(a,b):
    Y = a+b
    return Y

# %%
ad(3,5)
# Out:
# 8

# %% [markdown]
# # About Dataset

# %%
DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Brand                 30 non-null     object
#  1   Item ID               30 non-null     int64
#  2   Ram(Gb)               29 non-null     float64
#  3   StoraGe(Gb)           28 non-null     float64
#  4   Price(Rs)             30 non-null     int64
#  5   Processor speed(GHz)  30 non-null     float64
#  6    Touch                30 non-null     object
#  7   Color                 30 non-null     object
#  8   Weight                27 non-null     float64
#  9   DisplAy size(Inch)    30 non-null     float64
# dtypes: float64(5), int64(2), object(3)
# memory usage: 2.5+ KB

# %%
DF.nunique()
# Out:
# Brand                    2
# Item ID                  4
# Ram(Gb)                  5
# StoraGe(Gb)              7
# Price(Rs)               28
# Processor speed(GHz)    13
#  Touch                   2
# Color                    6
# Weight                  21
# DisplAy size(Inch)      12
# dtype: int64

# %%
DF.head(15)
# Out:
#     Brand  Item ID  Ram(Gb)  StoraGe(Gb)  Price(Rs)  Processor speed(GHz)  \
# 0   Apple       32     16.0        256.0     315000                   2.2
# 1   Apple        8      8.0        512.0     232000                   3.2
# 2   Apple       32     16.0       1024.0     382000                   2.3
# 3   Apple       26      8.0          NaN     195000                   2.3
# 4   Apple       32      4.0        128.0      92400                   1.8
# 5   Apple        4      8.0        256.0      60000                   2.6
# 6   Apple       32      8.0        512.0     192000                   1.2
# 7   Apple        4      8.0        128.0     224700                   1.8
# 8   Apple       26      8.0        128.0     102000                   1.6
# 9   Apple        4     16.0          NaN     382000                   2.6
# 10   Dell        8      4.0       1024.0      78500                   2.1
# 11   Dell       32      8.0        256.0      90000                   1.6
# 12   Dell        8      4.0       1024.0     100000                   2.4
# 13   Dell        8      NaN       1024.0     125000                   1.8
# 14   Dell        8      8.0        256.0     122000                   2.4
#
#     Touch       Color   Weight  DisplAy size(Inch)
# 0       No  Space grey    1.83                15.4
# 1       No  Dark Black    1.29                13.3
# 2       No      Silver    2.00                16.0
# 3       No  Space grey    1.37                13.3
# 4       No      Silver    1.35                11.6
# 5       No      Silver    1.00                13.3
# 6       No      Silver    0.90                12.0
# 7       No      Silver    1.23                13.3
# 8       No   Rose Gold    1.25                13.3
# 9       No      Silver    2.00                16.0
# 10      No       Black    1.90                15.6
# 11      No       Black    1.82                15.6
# 12      No       Black    1.78                15.6
# 13     Yes      Silver    1.90                15.6
# 14     Yes      Silver     NaN                14.0

# %% [markdown]
# # Groupby

# %%
DF.groupby("Item ID")["Price(Rs)"].min()
DF.groupby("Item ID")["Price(Rs)"].max()
DF.groupby("Item ID")["Price(Rs)"].mean()
DF.groupby("Item ID")["Price(Rs)"].count()
DF.groupby("Item ID")["Price(Rs)"].sum()
# Out:
# Item ID
# 4     1301700
# 8     1275700
# 26    1255000
# 32    1201400
# Name: Price(Rs), dtype: int64

# %% [markdown]
# # Map

# %%
Price_count_with_Item_ID = DF.groupby("Item ID")["Price(Rs)"].count()
Price_count_with_Item_ID

DF["Pricecount_respectiveto_ItemID"] = DF["Item ID"].map(Price_count_with_Item_ID)

# %%
DF.head(14)
# Out:
#     Brand  Item ID  Ram(Gb)  StoraGe(Gb)  Price(Rs)  Processor speed(GHz)  \
# 0   Apple       32     16.0        256.0     315000                   2.2
# 1   Apple        8      8.0        512.0     232000                   3.2
# 2   Apple       32     16.0       1024.0     382000                   2.3
# 3   Apple       26      8.0          NaN     195000                   2.3
# 4   Apple       32      4.0        128.0      92400                   1.8
# 5   Apple        4      8.0        256.0      60000                   2.6
# 6   Apple       32      8.0        512.0     192000                   1.2
# 7   Apple        4      8.0        128.0     224700                   1.8
# 8   Apple       26      8.0        128.0     102000                   1.6
# 9   Apple        4     16.0          NaN     382000                   2.6
# 10   Dell        8      4.0       1024.0      78500                   2.1
# 11   Dell       32      8.0        256.0      90000                   1.6
# 12   Dell        8      4.0       1024.0     100000                   2.4
# 13   Dell        8      NaN       1024.0     125000                   1.8
#
#     Touch       Color   Weight  DisplAy size(Inch)  \
# 0       No  Space grey    1.83                15.4
# 1       No  Dark Black    1.29                13.3
# 2       No      Silver    2.00                16.0
# 3       No  Space grey    1.37                13.3
# 4       No      Silver    1.35                11.6
# 5       No      Silver    1.00                13.3
# 6       No      Silver    0.90                12.0
# 7       No      Silver    1.23                13.3
# 8       No   Rose Gold    1.25                13.3
# 9       No      Silver    2.00                16.0
# 10      No       Black    1.90                15.6
# 11      No       Black    1.82                15.6
# 12      No       Black    1.78                15.6
# 13     Yes      Silver    1.90                15.6
#
#     Pricecount_respectiveto_ItemID
# 0                                6
# 1                               10
# 2                                6
# 3                                7
# 4                                6
# 5                                7
# 6                                6
# 7                                7
# 8                                7
# 9                                7
# 10                              10
# 11                               6
# 12                              10
# 13                              10

# %% [markdown]
# # Transform

# %%
DF["Pricecount_respectiveto_ItemID_T"] = DF.groupby("Item ID")["Price(Rs)"].transform('count')
DF["Weight"] = DF.groupby("Item ID")["Weight"].transform('sum')

# Not to work on categorical data
#DF["Touch"] = DF.groupby("Item ID")[" Touch "].transform('')

# %%
DF.head(15)
# Out:
#     Brand  Item ID  Ram(Gb)  StoraGe(Gb)  Price(Rs)  Processor speed(GHz)  \
# 0   Apple       32     16.0        256.0     315000                   2.2
# 1   Apple        8      8.0        512.0     232000                   3.2
# 2   Apple       32     16.0       1024.0     382000                   2.3
# 3   Apple       26      8.0          NaN     195000                   2.3
# 4   Apple       32      4.0        128.0      92400                   1.8
# 5   Apple        4      8.0        256.0      60000                   2.6
# 6   Apple       32      8.0        512.0     192000                   1.2
# 7   Apple        4      8.0        128.0     224700                   1.8
# 8   Apple       26      8.0        128.0     102000                   1.6
# 9   Apple        4     16.0          NaN     382000                   2.6
# 10   Dell        8      4.0       1024.0      78500                   2.1
# 11   Dell       32      8.0        256.0      90000                   1.6
# 12   Dell        8      4.0       1024.0     100000                   2.4
# 13   Dell        8      NaN       1024.0     125000                   1.8
# 14   Dell        8      8.0        256.0     122000                   2.4
#
#     Touch       Color   Weight  DisplAy size(Inch)  \
# 0       No  Space grey    9.85                15.4
# 1       No  Dark Black   14.16                13.3
# 2       No      Silver    9.85                16.0
# 3       No  Space grey    9.36                13.3
# 4       No      Silver    9.85                11.6
# 5       No      Silver   10.66                13.3
# 6       No      Silver    9.85                12.0
# 7       No      Silver   10.66                13.3
# 8       No   Rose Gold    9.36                13.3
# 9       No      Silver   10.66                16.0
# 10      No       Black   14.16                15.6
# 11      No       Black    9.85                15.6
# 12      No       Black   14.16                15.6
# 13     Yes      Silver   14.16                15.6
# 14     Yes      Silver   14.16                14.0
#
#     Pricecount_respectiveto_ItemID  Pricecount_respectiveto_ItemID_T
# 0                                6                                 6
# 1                               10                                10
# 2                                6                                 6
# 3                                7                                 7
# 4                                6                                 6
# 5                                7                                 7
# 6                                6                                 6
# 7                                7                                 7
# 8                                7                                 7
# 9                                7                                 7
# 10                              10                                10
# 11                               6                                 6
# 12                              10                                10
# 13                              10                                10
# 14                              10                                10
